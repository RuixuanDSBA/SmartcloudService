# %%
import sys
from awsglue.transforms import *
from awsglue.utils import getResolvedOptions
from pyspark.context import SparkContext
from awsglue.context import GlueContext
from awsglue.job import Job

glueContext = GlueContext(SparkContext.getOrCreate())
# Out:
# Welcome to the Glue Interactive Sessions Kernel
# For more information on available magic commands, please type %help in any new cell.
#
# Please view our Getting Started page to access the most up-to-date information on the Interactive Sessions kernel: https://docs.aws.amazon.com/glue/latest/dg/interactive-sessions.html
# Installed kernel version: 0.35
# Authenticating with environment variables and user-defined glue_role_arn: arn:aws:iam::087763889191:role/service-role/AWSGlueServiceRole-imba-nining
# Trying to create a Glue session for the kernel.
# Worker Type: G.1X
# Number of Workers: 5
# Session ID: bbe23e31-eb6f-4608-9ffe-e330843f2efe
# Applying the following default arguments:
# --glue_kernel_version 0.35
# --enable-glue-datacatalog true
# Waiting for session bbe23e31-eb6f-4608-9ffe-e330843f2efe to get into ready status...
# Session bbe23e31-eb6f-4608-9ffe-e330843f2efe has been created

# %%
#crawler the data from data source, then define raw data zone as database for the data.
orders = glueContext.create_dynamic_frame.from_catalog(database="raw data zone", table_name="orders")
print("Count: " + str(orders.count()))
print(type(orders))
orders.printSchema()

products = glueContext.create_dynamic_frame.from_catalog(database="raw data zone", table_name="products")
print("Count: " + str(products.count()))
products.printSchema()

order_products = glueContext.create_dynamic_frame.from_catalog(database="raw data zone", table_name="order_products")
print("Count: " + str(order_products.count()))
order_products.printSchema()
# Out:
# Count: 39
# <class 'awsglue.dynamicframe.DynamicFrame'>
# root
# |-- order_id: long
# |-- user_id: long
# |-- eval_set: string
# |-- order_number: long
# |-- order_dow: long
# |-- order_hour_of_day: long
# |-- days_since_prior_order: long
#
# Count: 49688
# root
# |-- product_id: long
# |-- product_name: string
# |-- aisle_id: long
# |-- department_id: long
#
# Count: 384
# root
# |-- order_id: long
# |-- product_id: long
# |-- add_to_cart_order: long
# |-- reordered: long
# |-- partition_0: string

# %%
#departments is just one table in database, so you can load other tables like aisles, orders, etc. one by one
df_orders = orders.toDF()
df_orders.show(5)

df_products = products.toDF()
df_products.show(5)

df_order_products = order_products.toDF()
df_order_products.show(5)
# Out:
# +--------+-------+--------+------------+---------+-----------------+----------------------+
# |order_id|user_id|eval_set|order_number|order_dow|order_hour_of_day|days_since_prior_order|
# +--------+-------+--------+------------+---------+-----------------+----------------------+
# | 2539329|      1|   prior|           1|        2|                8|                  null|
# | 2398795|      1|   prior|           2|        3|                7|                    15|
# |  473747|      1|   prior|           3|        3|               12|                    21|
# | 2254736|      1|   prior|           4|        4|                7|                    29|
# |  431534|      1|   prior|           5|        4|               15|                    28|
# +--------+-------+--------+------------+---------+-----------------+----------------------+
# only showing top 5 rows
#
# +----------+--------------------+--------+-------------+
# |product_id|        product_name|aisle_id|department_id|
# +----------+--------------------+--------+-------------+
# |         1|Chocolate Sandwic...|      61|           19|
# |         2|    All-Seasons Salt|     104|           13|
# |         3|Robust Golden Uns...|      94|            7|
# |         4|Smart Ones Classi...|      38|            1|
# |         5|Green Chile Anyti...|       5|           13|
# +----------+--------------------+--------+-------------+
# only showing top 5 rows
#
# +--------+----------+-----------------+---------+--------------------+
# |order_id|product_id|add_to_cart_order|reordered|         partition_0|
# +--------+----------+-----------------+---------+--------------------+
# | 1187899|       196|                1|        1|order_products_train|
# | 1187899|     25133|                2|        1|order_products_train|
# | 1187899|     38928|                3|        1|order_products_train|
# | 1187899|     26405|                4|        1|order_products_train|
# | 1187899|     39657|                5|        1|order_products_train|
# +--------+----------+-----------------+---------+--------------------+
# only showing top 5 rows

# %%
#data clean -- in this part, only one way, deduplication, is designed to demonstrate the clean process, you can add other methods to clean data
loc = locals()      #get string name
def get_variable_name(variable):
    for k,v in loc.items():
        if loc[k] is variable:
            return k


# def getString_name(df_name):
#      return list(dict(df_name = df_name).keys())[0]#,type(list(dict(df_name = df_name).values())[0])

def deduplicate_df(df_name):
    if df_name.count() != df_name.distinct().count():
        print( str(get_variable_name(df_name)) + ' have duplicated row:',df_name.count()- df_name.distinct().count())
        df_name = df_name.dropDuplicates()
        print('duplicated data has been cleared')
    else:
        print( str(get_variable_name(df_name)) + ' hasn\'t duplication, the totle distinct row',df_name.count())
    return df_name

df_orders_clean = deduplicate_df(df_orders)
df_orders_clean.show(5)
df_products_clean = deduplicate_df(df_products)
df_order_products_clean = deduplicate_df(df_order_products)
# Out:
# df_orders hasn't duplication, the totle distinct row 39
# +--------+-------+--------+------------+---------+-----------------+----------------------+
# |order_id|user_id|eval_set|order_number|order_dow|order_hour_of_day|days_since_prior_order|
# +--------+-------+--------+------------+---------+-----------------+----------------------+
# | 2539329|      1|   prior|           1|        2|                8|                  null|
# | 2398795|      1|   prior|           2|        3|                7|                    15|
# |  473747|      1|   prior|           3|        3|               12|                    21|
# | 2254736|      1|   prior|           4|        4|                7|                    29|
# |  431534|      1|   prior|           5|        4|               15|                    28|
# +--------+-------+--------+------------+---------+-----------------+----------------------+
# only showing top 5 rows
#
# df_products hasn't duplication, the totle distinct row 49688
# df_order_products hasn't duplication, the totle distinct row 384

# %%
# put cleaned departments table into my datalake 
df_products_clean =df_products_clean.repartition(1)
df_products_clean.write.parquet('s3://project-imba/data-lake/raw-data/products_clean)

# %%
wide_table_for_ML=(df_orders_clean.select("order_id","user_id","order_number")\
.join(df_order_products,df_orders_clean.order_id==df_order_products.order_id,"left")\
.drop(df_orders_clean.order_id)\
.join(df_products,df_products.product_id == df_order_products.product_id,"left")\
.drop(df_products.product_id)\
.orderBy("user_id",df_orders_clean.order_number,"add_to_cart_order")\
.drop("reordered","product_name"))\
.select("user_id","order_id","order_number","department_id","aisle_id","product_id","add_to_cart_order","partition_0")\

# %%
wide_table_for_ML.show(503)
# Out:
# +-------+--------+------------+-------------+--------+----------+-----------------+--------------------+
# |user_id|order_id|order_number|department_id|aisle_id|product_id|add_to_cart_order|         partition_0|
# +-------+--------+------------+-------------+--------+----------+-----------------+--------------------+
# |      1| 2539329|           1|            7|      77|       196|                1|order_products_prior|
# |      1| 2539329|           1|           16|      91|     14084|                2|order_products_prior|
# |      1| 2539329|           1|           19|      23|     12427|                3|order_products_prior|
# |      1| 2539329|           1|           19|      23|     26088|                4|order_products_prior|
# |      1| 2539329|           1|           17|      54|     26405|                5|order_products_prior|
# |      1| 2398795|           2|            7|      77|       196|                1|order_products_prior|
# |      1| 2398795|           2|           19|     117|     10258|                2|order_products_prior|
# |      1| 2398795|           2|           19|      23|     12427|                3|order_products_prior|
# |      1| 2398795|           2|            4|      24|     13176|                4|order_products_prior|
# |      1| 2398795|           2|           19|      23|     26088|                5|order_products_prior|
# |      1| 2398795|           2|           14|     121|     13032|                6|order_products_prior|
# |      1|  473747|           3|            7|      77|       196|                1|order_products_prior|
# |      1|  473747|           3|           19|      23|     12427|                2|order_products_prior|
# |      1|  473747|           3|           19|     117|     10258|                3|order_products_prior|
# |      1|  473747|           3|           16|      21|     25133|                4|order_products_prior|
# |      1|  473747|           3|           13|      88|     30450|                5|order_products_prior|
# |      1| 2254736|           4|            7|      77|       196|                1|order_products_prior|
# |      1| 2254736|           4|           19|      23|     12427|                2|order_products_prior|
# |      1| 2254736|           4|           19|     117|     10258|                3|order_products_prior|
# |      1| 2254736|           4|           16|      21|     25133|                4|order_products_prior|
# |      1| 2254736|           4|           17|      54|     26405|                5|order_products_prior|
# |      1|  431534|           5|            7|      77|       196|                1|order_products_prior|
# |      1|  431534|           5|           19|      23|     12427|                2|order_products_prior|
# |      1|  431534|           5|           19|     117|     10258|                3|order_products_prior|
# |      1|  431534|           5|           16|      21|     25133|                4|order_products_prior|
# |      1|  431534|           5|            4|      24|     10326|                5|order_products_prior|
# |      1|  431534|           5|            4|      24|     17122|                6|order_products_prior|
# |      1|  431534|           5|            4|      24|     41787|                7|order_products_prior|
# |      1|  431534|           5|            4|      24|     13176|                8|order_products_prior|
# |      1| 3367565|           6|            7|      77|       196|                1|order_products_prior|
# |      1| 3367565|           6|           19|      23|     12427|                2|order_products_prior|
# |      1| 3367565|           6|           19|     117|     10258|                3|order_products_prior|
# |      1| 3367565|           6|           16|      21|     25133|                4|order_products_prior|
# |      1|  550135|           7|            7|      77|       196|                1|order_products_prior|
# |      1|  550135|           7|           19|     117|     10258|                2|order_products_prior|
# |      1|  550135|           7|           19|      23|     12427|                3|order_products_prior|
# |      1|  550135|           7|           16|      21|     25133|                4|order_products_prior|
# |      1|  550135|           7|           14|     121|     13032|                5|order_products_prior|
# |      1| 3108588|           8|           19|      23|     12427|                1|order_products_prior|
# |      1| 3108588|           8|            7|      77|       196|                2|order_products_prior|
# |      1| 3108588|           8|           19|     117|     10258|                3|order_products_prior|
# |      1| 3108588|           8|           16|      21|     25133|                4|order_products_prior|
# |      1| 3108588|           8|            7|      77|     46149|                5|order_products_prior|
# |      1| 3108588|           8|           16|      53|     49235|                6|order_products_prior|
# |      1| 2295261|           9|           16|      53|     49235|                1|order_products_prior|
# |      1| 2295261|           9|            7|      77|     46149|                2|order_products_prior|
# |      1| 2295261|           9|           16|      21|     25133|                3|order_products_prior|
# |      1| 2295261|           9|            7|      77|       196|                4|order_products_prior|
# |      1| 2295261|           9|           19|     117|     10258|                5|order_products_prior|
# |      1| 2295261|           9|           19|      23|     12427|                6|order_products_prior|
# |      1| 2550362|          10|            7|      77|       196|                1|order_products_prior|
# |      1| 2550362|          10|            7|      77|     46149|                2|order_products_prior|
# |      1| 2550362|          10|           19|      45|     39657|                3|order_products_prior|
# |      1| 2550362|          10|           16|     120|     38928|                4|order_products_prior|
# |      1| 2550362|          10|           16|      21|     25133|                5|order_products_prior|
# |      1| 2550362|          10|           19|     117|     10258|                6|order_products_prior|
# |      1| 2550362|          10|           16|      91|     35951|                7|order_products_prior|
# |      1| 2550362|          10|           14|     121|     13032|                8|order_products_prior|
# |      1| 2550362|          10|           19|      23|     12427|                9|order_products_prior|
# |      1| 1187899|          11|            7|      77|       196|                1|order_products_train|
# |      1| 1187899|          11|           16|      21|     25133|                2|order_products_train|
# |      1| 1187899|          11|           16|     120|     38928|                3|order_products_train|
# |      1| 1187899|          11|           17|      54|     26405|                4|order_products_train|
# |      1| 1187899|          11|           19|      45|     39657|                5|order_products_train|
# |      1| 1187899|          11|           19|     117|     10258|                6|order_products_train|
# |      1| 1187899|          11|           14|     121|     13032|                7|order_products_train|
# |      1| 1187899|          11|           19|      23|     26088|                8|order_products_train|
# |      1| 1187899|          11|           16|      84|     27845|                9|order_products_train|
# |      1| 1187899|          11|           16|      53|     49235|               10|order_products_train|
# |      1| 1187899|          11|            7|      77|     46149|               11|order_products_train|
# |      2| 2168274|           1|           19|      23|     32792|                1|order_products_prior|
# |      2| 2168274|           1|            4|      24|     47766|                2|order_products_prior|
# |      2| 2168274|           1|           20|      96|     20574|                3|order_products_prior|
# |      2| 2168274|           1|           13|      72|     12000|                4|order_products_prior|
# |      2| 2168274|           1|           19|      78|     48110|                5|order_products_prior|
# |      2| 2168274|           1|           19|      78|     22474|                6|order_products_prior|
# |      2| 2168274|           1|           19|     107|     16589|                7|order_products_prior|
# |      2| 2168274|           1|            7|      98|     35917|                8|order_products_prior|
# |      2| 2168274|           1|           20|      96|     27344|                9|order_products_prior|
# |      2| 2168274|           1|           20|      67|     30489|               10|order_products_prior|
# |      2| 2168274|           1|            4|     123|     27966|               11|order_products_prior|
# |      2| 2168274|           1|            4|      24|     13176|               12|order_products_prior|
# |      2| 2168274|           1|            4|      24|     45066|               13|order_products_prior|
# |      2| 1501582|           2|            4|      24|     16797|                1|order_products_prior|
# |      2| 1501582|           2|           16|      21|     47526|                2|order_products_prior|
# |      2| 1501582|           2|           19|      78|      8479|                3|order_products_prior|
# |      2| 1501582|           2|            4|      24|     47766|                4|order_products_prior|
# |      2| 1501582|           2|           19|     107|     19051|                5|order_products_prior|
# |      2| 1501582|           2|           20|      67|      8138|                6|order_products_prior|
# |      2| 1901567|           3|            4|      24|     47766|                1|order_products_prior|
# |      2| 1901567|           3|           19|      23|     32792|                2|order_products_prior|
# |      2| 1901567|           3|           20|      96|     20574|                3|order_products_prior|
# |      2| 1901567|           3|           16|      21|      7781|                4|order_products_prior|
# |      2| 1901567|           3|           20|       1|     28874|                5|order_products_prior|
# |      2|  738281|           4|           20|      67|     49451|                1|order_products_prior|
# |      2|  738281|           4|           19|      23|     32792|                2|order_products_prior|
# |      2|  738281|           4|           20|      67|     32139|                3|order_products_prior|
# |      2|  738281|           4|            7|      31|     34688|                4|order_products_prior|
# |      2|  738281|           4|           20|      96|     36735|                5|order_products_prior|
# |      2|  738281|           4|            4|      24|     37646|                6|order_products_prior|
# |      2|  738281|           4|           19|      78|     22829|                7|order_products_prior|
# |      2|  738281|           4|            4|      24|     24852|                8|order_products_prior|
# |      2|  738281|           4|            4|      24|     47209|                9|order_products_prior|
# |      2|  738281|           4|           20|      67|     33276|               10|order_products_prior|
# |      2|  738281|           4|            1|      38|     45613|               11|order_products_prior|
# |      2|  738281|           4|            1|      38|      9681|               12|order_products_prior|
# |      2|  738281|           4|            1|      38|     21150|               13|order_products_prior|
# |      2| 1673511|           5|           16|      91|     47144|                1|order_products_prior|
# |      2| 1673511|           5|           19|       3|      5322|                2|order_products_prior|
# |      2| 1673511|           5|           19|       3|     17224|                3|order_products_prior|
# |      2| 1673511|           5|           19|       3|     38656|                4|order_products_prior|
# |      2| 1673511|           5|           19|     107|     21376|                5|order_products_prior|
# |      2| 1673511|           5|           14|      48|     48210|                6|order_products_prior|
# |      2| 1673511|           5|           14|      48|      5907|                7|order_products_prior|
# |      2| 1673511|           5|           14|      57|     14553|                8|order_products_prior|
# |      2| 1673511|           5|           11|      20|     47553|                9|order_products_prior|
# |      2| 1673511|           5|           16|     120|     22124|               10|order_products_prior|
# |      2| 1673511|           5|           16|     120|     19156|               11|order_products_prior|
# |      2| 1673511|           5|           16|     120|      1559|               12|order_products_prior|
# |      2| 1673511|           5|            4|      24|     47766|               13|order_products_prior|
# |      2| 1199898|           6|           19|      23|     32792|                1|order_products_prior|
# |      2| 1199898|           6|           13|      72|     12000|                2|order_products_prior|
# |      2| 1199898|           6|            1|      38|      9681|                3|order_products_prior|
# |      2| 1199898|           6|           20|      67|     32139|                4|order_products_prior|
# |      2| 1199898|           6|           19|      78|     32052|                5|order_products_prior|
# |      2| 1199898|           6|           20|      96|     27344|                6|order_products_prior|
# |      2| 1199898|           6|            4|      24|     24852|                7|order_products_prior|
# |      2| 1199898|           6|            4|      24|     45066|                8|order_products_prior|
# |      2| 1199898|           6|            4|     123|     27966|                9|order_products_prior|
# |      2| 1199898|           6|            4|      24|     47209|               10|order_products_prior|
# |      2| 1199898|           6|           20|      96|     36735|               11|order_products_prior|
# |      2| 1199898|           6|           16|     120|     46676|               12|order_products_prior|
# |      2| 1199898|           6|           16|     120|     33754|               13|order_products_prior|
# |      2| 1199898|           6|           16|     120|     17872|               14|order_products_prior|
# |      2| 1199898|           6|           16|     120|     18523|               15|order_products_prior|
# |      2| 1199898|           6|           16|     120|     24954|               16|order_products_prior|
# |      2| 1199898|           6|           16|     120|      4957|               17|order_products_prior|
# |      2| 1199898|           6|           16|     120|     40571|               18|order_products_prior|
# |      2| 1199898|           6|            4|      24|     41787|               19|order_products_prior|
# |      2| 1199898|           6|           19|     107|     19051|               20|order_products_prior|
# |      2| 1199898|           6|           20|      67|     33276|               21|order_products_prior|
# |      2| 3194192|           7|           19|      23|     32792|                1|order_products_prior|
# |      2| 3194192|           7|           13|      72|     12000|                2|order_products_prior|
# |      2| 3194192|           7|           19|     107|     16589|                3|order_products_prior|
# |      2| 3194192|           7|           19|      78|     32052|                4|order_products_prior|
# |      2| 3194192|           7|           19|     107|     19051|                5|order_products_prior|
# |      2| 3194192|           7|           20|      67|     32139|                6|order_products_prior|
# |      2| 3194192|           7|            4|      24|     47209|                7|order_products_prior|
# |      2| 3194192|           7|            4|      24|     24852|                8|order_products_prior|
# |      2| 3194192|           7|           16|     120|     46886|                9|order_products_prior|
# |      2| 3194192|           7|           16|     120|     40198|               10|order_products_prior|
# |      2| 3194192|           7|           16|     120|     17758|               11|order_products_prior|
# |      2| 3194192|           7|            4|      24|     45066|               12|order_products_prior|
# |      2| 3194192|           7|            4|      24|     41787|               13|order_products_prior|
# |      2| 3194192|           7|            7|      31|     34688|               14|order_products_prior|
# |      2|  788338|           8|           19|      23|     32792|                1|order_products_prior|
# |      2|  788338|           8|           19|     117|     28918|                2|order_products_prior|
# |      2|  788338|           8|            4|      24|     24852|                3|order_products_prior|
# |      2|  788338|           8|            7|      31|     34688|                4|order_products_prior|
# |      2|  788338|           8|           19|      78|     48110|                5|order_products_prior|
# |      2|  788338|           8|            4|      24|     47209|                6|order_products_prior|
# |      2|  788338|           8|           19|      78|     32052|                7|order_products_prior|
# |      2|  788338|           8|           16|     120|     17758|                8|order_products_prior|
# |      2|  788338|           8|           16|     120|     40198|                9|order_products_prior|
# |      2|  788338|           8|           16|     120|     46886|               10|order_products_prior|
# |      2|  788338|           8|           20|      96|     22963|               11|order_products_prior|
# |      2|  788338|           8|           12|      49|        23|               12|order_products_prior|
# |      2|  788338|           8|            7|      31|     20084|               13|order_products_prior|
# |      2|  788338|           8|            1|      42|      2002|               14|order_products_prior|
# |      2|  788338|           8|            4|     123|      5212|               15|order_products_prior|
# |      2|  788338|           8|           13|     110|     14306|               16|order_products_prior|
# |      2| 1718559|           9|           19|      23|     32792|                1|order_products_prior|
# |      2| 1718559|           9|            4|      24|     24852|                2|order_products_prior|
# |      2| 1718559|           9|           13|      72|     12000|                3|order_products_prior|
# |      2| 1718559|           9|           19|     107|     21376|                4|order_products_prior|
# |      2| 1718559|           9|            1|      42|      2002|                5|order_products_prior|
# |      2| 1718559|           9|           16|      21|      7781|                6|order_products_prior|
# |      2| 1718559|           9|           19|       3|     13742|                7|order_products_prior|
# |      2| 1718559|           9|           19|       3|     18961|                8|order_products_prior|
# |      2| 1718559|           9|           19|       3|     15841|                9|order_products_prior|
# |      2| 1718559|           9|           16|     120|     33754|               10|order_products_prior|
# |      2| 1718559|           9|           16|     120|     22124|               11|order_products_prior|
# |      2| 1718559|           9|           16|     120|     19156|               12|order_products_prior|
# |      2| 1718559|           9|           16|     120|      1559|               13|order_products_prior|
# |      2| 1718559|           9|           16|     120|     13351|               14|order_products_prior|
# |      2| 1718559|           9|           16|     120|     18523|               15|order_products_prior|
# |      2| 1718559|           9|           16|     120|     17872|               16|order_products_prior|
# |      2| 1718559|           9|            4|      24|      5450|               17|order_products_prior|
# |      2| 1718559|           9|           19|      78|     22474|               18|order_products_prior|
# |      2| 1718559|           9|            1|      38|     48099|               19|order_products_prior|
# |      2| 1718559|           9|            1|      38|     49273|               20|order_products_prior|
# |      2| 1718559|           9|            1|      38|     47792|               21|order_products_prior|
# |      2| 1718559|           9|            1|      38|     45613|               22|order_products_prior|
# |      2| 1718559|           9|            1|      38|      9124|               23|order_products_prior|
# |      2| 1718559|           9|            1|      38|     22559|               24|order_products_prior|
# |      2| 1718559|           9|            1|      38|     33957|               25|order_products_prior|
# |      2| 1718559|           9|            1|      38|     27737|               26|order_products_prior|
# |      2| 1447487|          10|            4|      24|     24852|                1|order_products_prior|
# |      2| 1447487|          10|           13|      72|     12000|                2|order_products_prior|
# |      2| 1447487|          10|            4|      24|     47209|                3|order_products_prior|
# |      2| 1447487|          10|           16|     120|     17872|                4|order_products_prior|
# |      2| 1447487|          10|           16|     120|     18523|                5|order_products_prior|
# |      2| 1447487|          10|           16|     120|      1559|                6|order_products_prior|
# |      2| 1447487|          10|           16|     120|     19156|                7|order_products_prior|
# |      2| 1447487|          10|            1|      42|      2002|                8|order_products_prior|
# |      2| 1447487|          10|            6|      66|      2573|                9|order_products_prior|
# |      2| 1402090|          11|           19|      23|     32792|                1|order_products_prior|
# |      2| 1402090|          11|            6|      66|      4071|                2|order_products_prior|
# |      2| 1402090|          11|           19|     107|     19051|                3|order_products_prior|
# |      2| 1402090|          11|           16|     120|     19156|                4|order_products_prior|
# |      2| 1402090|          11|           16|     120|     18523|                5|order_products_prior|
# |      2| 1402090|          11|           16|     120|      1559|                6|order_products_prior|
# |      2| 1402090|          11|           16|     120|     22124|                7|order_products_prior|
# |      2| 1402090|          11|           16|     120|     33754|                8|order_products_prior|
# |      2| 1402090|          11|           19|      78|     22474|                9|order_products_prior|
# |      2| 1402090|          11|           19|     107|     16589|               10|order_products_prior|
# |      2| 1402090|          11|           20|      67|     32139|               11|order_products_prior|
# |      2| 1402090|          11|           19|      78|      8296|               12|order_products_prior|
# |      2| 1402090|          11|            4|      24|     47209|               13|order_products_prior|
# |      2| 1402090|          11|            1|      42|      2002|               14|order_products_prior|
# |      2| 1402090|          11|           20|      14|     21227|               15|order_products_prior|
# |      2| 3186735|          12|           19|      23|     32792|                1|order_products_prior|
# |      2| 3186735|          12|            4|      24|     47209|                2|order_products_prior|
# |      2| 3186735|          12|           16|     120|     22124|                3|order_products_prior|
# |      2| 3186735|          12|           16|     120|     19156|                4|order_products_prior|
# |      2| 3186735|          12|           16|     120|      1559|                5|order_products_prior|
# |      2| 3186735|          12|           16|     120|     13351|                6|order_products_prior|
# |      2| 3186735|          12|            7|      94|      3151|                7|order_products_prior|
# |      2| 3186735|          12|           19|     107|     19240|                8|order_products_prior|
# |      2| 3186735|          12|            7|     115|     21709|                9|order_products_prior|
# |      2| 3186735|          12|            4|      24|     10305|               10|order_products_prior|
# |      2| 3186735|          12|           19|     117|     24990|               11|order_products_prior|
# |      2| 3186735|          12|           16|     120|     18523|               12|order_products_prior|
# |      2| 3186735|          12|           20|      96|     36735|               13|order_products_prior|
# |      2| 3186735|          12|           20|      96|     22963|               14|order_products_prior|
# |      2| 3186735|          12|           16|     120|     33754|               15|order_products_prior|
# |      2| 3186735|          12|           19|     107|     16589|               16|order_products_prior|
# |      2| 3186735|          12|           13|      88|     36287|               17|order_products_prior|
# |      2| 3186735|          12|           13|      88|     42356|               18|order_products_prior|
# |      2| 3186735|          12|            3|      93|     12258|               19|order_products_prior|
# |      2| 3268552|          13|           20|      96|     42342|                1|order_products_prior|
# |      2| 3268552|          13|           19|      23|     30908|                2|order_products_prior|
# |      2| 3268552|          13|           15|      95|        79|                3|order_products_prior|
# |      2| 3268552|          13|           13|      17|      5869|                4|order_products_prior|
# |      2| 3268552|          13|           13|      17|     44303|                5|order_products_prior|
# |      2| 3268552|          13|           19|     117|     16521|                6|order_products_prior|
# |      2| 3268552|          13|            4|      24|     39877|                7|order_products_prior|
# |      2| 3268552|          13|            4|      24|     19057|                8|order_products_prior|
# |      2| 3268552|          13|            3|     112|     45948|                9|order_products_prior|
# |      2|  839880|          14|            4|      24|     24852|                1|order_products_prior|
# |      2|  839880|          14|           19|     107|     16589|                2|order_products_prior|
# |      2|  839880|          14|           16|     120|      1559|                3|order_products_prior|
# |      2|  839880|          14|           16|     120|     19156|                4|order_products_prior|
# |      2|  839880|          14|           16|     120|     18523|                5|order_products_prior|
# |      2|  839880|          14|            4|      24|     22825|                6|order_products_prior|
# |      2|  839880|          14|            7|      31|     27413|                7|order_products_prior|
# |      2|  839880|          14|           16|     120|     33754|                8|order_products_prior|
# |      2|  839880|          14|            7|     115|     21709|                9|order_products_prior|
# |      2|  839880|          14|            4|      24|     47209|               10|order_products_prior|
# |      2|  839880|          14|           16|      21|      7781|               11|order_products_prior|
# |      2|  839880|          14|            6|      66|      2573|               12|order_products_prior|
# |      2|  839880|          14|            4|      24|     39928|               13|order_products_prior|
# |      2|  839880|          14|           16|      21|     20785|               14|order_products_prior|
# |      2|  839880|          14|           13|      88|     24768|               15|order_products_prior|
# |      2|  839880|          14|            1|      58|      7963|               16|order_products_prior|
# |      2| 1492625|          15|           20|      96|     22963|                1|order_products_train|
# |      2| 1492625|          15|            1|      58|      7963|                2|order_products_train|
# |      2| 1492625|          15|           19|     107|     16589|                3|order_products_train|
# |      2| 1492625|          15|           19|      23|     32792|                4|order_products_train|
# |      2| 1492625|          15|            4|      24|     41787|                5|order_products_train|
# |      2| 1492625|          15|            4|      24|     22825|                6|order_products_train|
# |      2| 1492625|          15|            4|      24|     13640|                7|order_products_train|
# |      2| 1492625|          15|            4|      24|     24852|                8|order_products_train|
# |      2| 1492625|          15|            4|      24|     45066|                9|order_products_train|
# |      2| 1492625|          15|            4|      24|      9387|               10|order_products_train|
# |      2| 1492625|          15|            4|      24|      5450|               11|order_products_train|
# |      2| 1492625|          15|           16|      91|     24838|               12|order_products_train|
# |      2| 1492625|          15|           19|      46|     38547|               13|order_products_train|
# |      2| 1492625|          15|           20|      96|     19019|               14|order_products_train|
# |      2| 1492625|          15|           11|      80|     12007|               15|order_products_train|
# |      2| 1492625|          15|           20|       1|     26352|               16|order_products_train|
# |      2| 1492625|          15|            1|      38|     22559|               17|order_products_train|
# |      2| 1492625|          15|            1|      38|     45613|               18|order_products_train|
# |      2| 1492625|          15|            1|      38|     31883|               19|order_products_train|
# |      2| 1492625|          15|            1|      38|     12324|               20|order_products_train|
# |      2| 1492625|          15|            1|      38|     33957|               21|order_products_train|
# |      2| 1492625|          15|            1|      38|      5699|               22|order_products_train|
# |      2| 1492625|          15|            1|      38|     31612|               23|order_products_train|
# |      2| 1492625|          15|           15|      69|     34284|               24|order_products_train|
# |      2| 1492625|          15|            1|      37|     48523|               25|order_products_train|
# |      2| 1492625|          15|            1|      37|      2361|               26|order_products_train|
# |      2| 1492625|          15|            1|      37|     48821|               27|order_products_train|
# |      2| 1492625|          15|           19|     117|     11913|               28|order_products_train|
# |      2| 1492625|          15|           19|       3|     45645|               29|order_products_train|
# |      2| 1492625|          15|           15|      69|      1757|               30|order_products_train|
# |      2| 1492625|          15|           15|      69|     21329|               31|order_products_train|
# |      3| 1374495|           1|            4|      24|      9387|                1|order_products_prior|
# |      3| 1374495|           1|           16|      91|     17668|                2|order_products_prior|
# |      3| 1374495|           1|            4|      24|     15143|                3|order_products_prior|
# |      3| 1374495|           1|            4|      24|     16797|                4|order_products_prior|
# |      3| 1374495|           1|           16|      91|     39190|                5|order_products_prior|
# |      3| 1374495|           1|            4|      24|     47766|                6|order_products_prior|
# |      3| 1374495|           1|            4|     123|     21903|                7|order_products_prior|
# |      3| 1374495|           1|            4|     123|     39922|                8|order_products_prior|
# |      3| 1374495|           1|           19|      78|     24810|                9|order_products_prior|
# |      3| 1374495|           1|           19|      78|     32402|               10|order_products_prior|
# |      3|  444309|           2|           16|     108|     38596|                1|order_products_prior|
# |      3|  444309|           2|            4|     123|     21903|                2|order_products_prior|
# |      3|  444309|           2|           19|     117|       248|                3|order_products_prior|
# |      3|  444309|           2|           16|      21|     40604|                4|order_products_prior|
# |      3|  444309|           2|           17|      54|      8021|                5|order_products_prior|
# |      3|  444309|           2|           16|      91|     17668|                6|order_products_prior|
# |      3|  444309|           2|            4|      24|     21137|                7|order_products_prior|
# |      3|  444309|           2|            7|     115|     23650|                8|order_products_prior|
# |      3|  444309|           2|           19|      78|     32402|                9|order_products_prior|
# |      3| 3002854|           3|           16|      91|     39190|                1|order_products_prior|
# |      3| 3002854|           3|            4|      24|     47766|                2|order_products_prior|
# |      3| 3002854|           3|            4|     123|     21903|                3|order_products_prior|
# |      3| 3002854|           3|            4|      83|     49683|                4|order_products_prior|
# |      3| 3002854|           3|           20|      13|     28373|                5|order_products_prior|
# |      3| 3002854|           3|           19|     117|      7503|                6|order_products_prior|
# |      3| 2037211|           4|           13|      88|      1819|                1|order_products_prior|
# |      3| 2037211|           4|           19|     117|     12845|                2|order_products_prior|
# |      3| 2037211|           4|            4|      24|      9387|                3|order_products_prior|
# |      3| 2037211|           4|            1|      37|     16965|                4|order_products_prior|
# |      3| 2037211|           4|            1|      52|     24010|                5|order_products_prior|
# |      3| 2710558|           5|           16|      91|     39190|                1|order_products_prior|
# |      3| 2710558|           5|            4|      24|      9387|                2|order_products_prior|
# |      3| 2710558|           5|           16|      91|     17668|                3|order_products_prior|
# |      3| 2710558|           5|            4|      24|     47766|                4|order_products_prior|
# |      3| 2710558|           5|            1|      37|     16965|                5|order_products_prior|
# |      3| 2710558|           5|           20|      13|     28373|                6|order_products_prior|
# |      3| 2710558|           5|            4|     123|     21903|                7|order_products_prior|
# |      3| 2710558|           5|           16|      21|     22035|                8|order_products_prior|
# |      3| 2710558|           5|            4|     123|     42265|                9|order_products_prior|
# |      3| 2710558|           5|           16|      21|     18370|               10|order_products_prior|
# |      3| 2710558|           5|            4|      83|     44683|               11|order_products_prior|
# |      3| 1972919|           6|           16|      21|     22035|                1|order_products_prior|
# |      3| 1972919|           6|           16|      91|     39190|                2|order_products_prior|
# |      3| 1972919|           6|            4|      24|      9387|                3|order_products_prior|
# |      3| 1972919|           6|            4|      24|     47766|                4|order_products_prior|
# |      3| 1972919|           6|           13|      88|      1819|                5|order_products_prior|
# |      3| 1972919|           6|           19|      78|     24810|                6|order_products_prior|
# |      3| 1972919|           6|            4|      83|     14992|                7|order_products_prior|
# |      3| 1972919|           6|            4|      83|     44683|                8|order_products_prior|
# |      3| 1839752|           7|           16|      91|     39190|                1|order_products_prior|
# |      3| 1839752|           7|           13|      88|      1819|                2|order_products_prior|
# |      3| 1839752|           7|            4|     123|     21903|                3|order_products_prior|
# |      3| 1839752|           7|            4|     123|     43961|                4|order_products_prior|
# |      3| 1839752|           7|            4|      24|     16797|                5|order_products_prior|
# |      3| 1839752|           7|            1|      52|     24010|                6|order_products_prior|
# |      3| 1839752|           7|            4|      83|     14992|                7|order_products_prior|
# |      3| 1839752|           7|            9|       4|     18599|                8|order_products_prior|
# |      3| 1839752|           7|            4|      24|      9387|                9|order_products_prior|
# |      3| 3225766|           8|           16|      91|     39190|                1|order_products_prior|
# |      3| 3225766|           8|           16|      21|     22035|                2|order_products_prior|
# |      3| 3225766|           8|            4|     123|     43961|                3|order_products_prior|
# |      3| 3225766|           8|            9|       4|     18599|                4|order_products_prior|
# |      3| 3225766|           8|            4|     123|     21903|                5|order_products_prior|
# |      3| 3225766|           8|            4|      24|     47766|                6|order_products_prior|
# |      3| 3225766|           8|           13|      88|     42557|                7|order_products_prior|
# |      3| 3225766|           8|            1|      37|     48523|                8|order_products_prior|
# |      3| 3160850|           9|           16|      91|     39190|                1|order_products_prior|
# |      3| 3160850|           9|            4|      24|     47766|                2|order_products_prior|
# |      3| 3160850|           9|            4|      24|     16797|                3|order_products_prior|
# |      3| 3160850|           9|            4|     123|     43961|                4|order_products_prior|
# |      3| 3160850|           9|            1|      37|     48523|                5|order_products_prior|
# |      3|  676467|          10|            9|       4|     18599|                1|order_products_prior|
# |      3|  676467|          10|           16|      91|     17668|                2|order_products_prior|
# |      3|  676467|          10|            4|      24|     47766|                3|order_products_prior|
# |      3|  676467|          10|           16|      91|     39190|                4|order_products_prior|
# |      3|  676467|          10|            7|      94|      1005|                5|order_products_prior|
# |      3|  676467|          10|           19|      78|     32402|                6|order_products_prior|
# |      3|  521107|          11|           16|      91|     39190|                1|order_products_prior|
# |      3|  521107|          11|            4|      24|     47766|                2|order_products_prior|
# |      3|  521107|          11|            4|     123|     21903|                3|order_products_prior|
# |      3|  521107|          11|            4|     123|     43961|                4|order_products_prior|
# |      3|  521107|          11|           16|      91|     17668|                5|order_products_prior|
# |      3| 1402502|          12|           16|      91|     39190|                1|order_products_prior|
# |      3| 1402502|          12|            9|       4|     18599|                2|order_products_prior|
# |      3| 1402502|          12|            7|     115|     23650|                3|order_products_prior|
# |      3| 1402502|          12|            4|     123|     21903|                4|order_products_prior|
# |      3| 1402502|          12|            4|      24|     47766|                5|order_products_prior|
# |      3| 1402502|          12|           19|      78|     24810|                6|order_products_prior|
# |      3|    null|          13|         null|    null|      null|             null|                null|
# +-------+--------+------------+-------------+--------+----------+-----------------+--------------------+
